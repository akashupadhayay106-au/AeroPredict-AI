# %% [markdown]
# # AeroPredict AI - 05 Deep Learning
#
# This notebook trains Deep Learning models (LSTM, GRU, 1D CNN) for sequence-based RUL prediction.

# %%
from src.train_dl import train_all_dl

print("Training DL Models...")
# Note: Deep learning models use SequenceBuilder to create 3D tensors (samples, timesteps, features).
# train_all_dl()
