# %% [markdown]
# # AeroPredict AI - 06 Explainability
#
# Using SHAP to understand model decisions locally and globally.

# %%
import shap
import joblib
from src.config import MODEL_DIR
import os

model_path = os.path.join(MODEL_DIR, "best_ml_model.pkl")
if os.path.exists(model_path):
    model = joblib.load(model_path)
    print("Model loaded successfully for SHAP analysis.")
else:
    print("Train models first to generate SHAP plots.")
