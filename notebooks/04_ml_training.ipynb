# %% [markdown]
# # AeroPredict AI - 04 ML Training
#
# This notebook trains classical Machine Learning models (Linear Regression, Random Forest, XGBoost, LightGBM) to predict the RUL. We compare their RMSE and MAE.

# %%
from src.train_ml import train_and_evaluate_ml

print("Training ML Models...")
# Note: In production, run `python scripts/train_all.py`. This notebook is for demonstration.
# train_and_evaluate_ml()

print("Models evaluate performance on the validation set, preventing data leakage across engines.")
