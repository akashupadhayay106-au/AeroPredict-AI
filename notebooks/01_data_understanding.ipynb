# %% [markdown]
# # AeroPredict AI - 01 Data Understanding
#
# This notebook explores the raw NASA C-MAPSS dataset. The dataset consists of multiple multivariate time-series representing turbofan engines running to failure.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from src.data_loader import load_cmapss_data

print("Loading FD001 Train Data...")
train_df = load_cmapss_data('train', 'FD001')
display(train_df.head())

# %% [markdown]
# ### Understanding Engine Lifecycles
# Each `unit_number` is an independent engine. The `time_cycles` column increments by 1 for each operational cycle. The engines operate until failure in the training set.
